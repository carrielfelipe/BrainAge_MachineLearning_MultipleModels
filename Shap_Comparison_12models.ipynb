# %%
path=  'C:/Users/felip/OneDrive - Universidad Técnica Federico Santa María/Documentos/Brain/'
#import sys
#sys.path.append(path) 
path_=  'C:/Users/felip/OneDrive - Universidad Técnica Federico Santa María/Documentos/Brain/Brain_Model/'
import sys
sys.path.append(path_)

# %%
#72 features
features = ['Alpha2_canon_EPP_HPC_left', 'Alpha2_canon_EPP_HPC_right', 'Alpha2_canon_EPP_PARIET_left', 'Alpha2_canon_EPP_PARIET_right', 'Alpha2_canon_EPP_OCC_left', 'Alpha2_canon_EPP_OCC_right', 'Alpha2_canon_RPD_HPC_left', 'Alpha2_canon_RPD_HPC_right', 'Alpha2_canon_RPD_CING_left', 'Alpha2_canon_RPD_CING_right', 'Alpha2_canon_RPD_PARIET_left', 'Alpha2_canon_RPD_PARIET_right', 'Alpha2_canon_RPD_OCC_left', 'Alpha2_canon_RPD_OCC_right', 'High_subj_spec_EPP_HPC_left', 'High_subj_spec_EPP_HPC_right', 'High_subj_spec_EPP_CING_left', 'High_subj_spec_EPP_CING_right', 'High_subj_spec_EPP_PARIET_left', 'High_subj_spec_EPP_PARIET_right', 'High_subj_spec_EPP_OCC_left', 'High_subj_spec_EPP_OCC_right', 'High_subj_spec_RPD_HPC_left', 'High_subj_spec_RPD_HPC_right', 'High_subj_spec_RPD_CING_left', 'High_subj_spec_RPD_CING_right', 'High_subj_spec_RPD_PARIET_left', 'High_subj_spec_RPD_PARIET_right', 'High_subj_spec_RPD_OCC_left', 'High_subj_spec_RPD_OCC_right', 'Low_subj_spec_EPP_HPC_left', 'Low_subj_spec_EPP_HPC_right', 'Low_subj_spec_EPP_CING_left', 'Low_subj_spec_EPP_CING_right', 'Low_subj_spec_EPP_PARIET_left', 'Low_subj_spec_EPP_PARIET_right', 'Low_subj_spec_EPP_OCC_left', 'Low_subj_spec_EPP_OCC_right', 'Low_subj_spec_RPD_HPC_left', 'Low_subj_spec_RPD_HPC_right', 'Low_subj_spec_RPD_CING_left', 'Low_subj_spec_RPD_CING_right', 'Low_subj_spec_RPD_PARIET_left', 'Low_subj_spec_RPD_PARIET_right', 'Low_subj_spec_RPD_OCC_left', 'Low_subj_spec_RPD_OCC_right', 'TF_ORB_left', 'TF_ORB_right', 'TF_IFG_left', 'TF_IFG_right', 'TF_MFG_left', 'TF_MFG_right', 'TF_SFG_left', 'TF_SFG_right', 'TF_HPC_left', 'TF_HPC_right', 'TF_INS_left', 'TF_INS_right', 'IAF_ORB_left', 'IAF_ORB_right', 'IAF_IFG_left', 'IAF_IFG_right', 'IAF_MFG_left', 'IAF_MFG_right', 'IAF_SFG_left', 'IAF_SFG_right', 'IAF_HPC_left', 'IAF_HPC_right', 'IAF_INS_left', 'IAF_INS_right', 'IAF_OCC_left', 'IAF_OCC_right']

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import pickle

file_path_CN = f'{path}Brain_Age/Data/CN_freq.xlsx'

df_CN = pd.read_excel(file_path_CN)


df_CN_filtrado = df_CN[(df_CN['Age'] >=20) & (df_CN['Age'] <= 90)].reset_index(drop=True)


X_CN = df_CN_filtrado[features]
y_CN = df_CN_filtrado["Age"]
ID_CN = df_CN_filtrado["ID_unique"]

#Scaler segun algoritmo
scaler = MinMaxScaler()
scaler.fit(X_CN)

X_CN_scaled = scaler.transform(X_CN)

X_CN_scaled = pd.DataFrame(X_CN_scaled, columns=X_CN.columns)

df_concatenado_CN = pd.concat([X_CN, y_CN, ID_CN], axis=1, ignore_index=False)

# %%
with open('BaggedKNN/results_model/multiple_shap_summary_sorted_CN.pkl', 'rb') as f:
    multiple_shap_summary_sorted_BaggedKNN = pickle.load(f)

with open('BaggedKNN/results_model/multiple_shap_values_CN.pkl', 'rb') as f:
    multiple_shap_values_BaggedKNN = pickle.load(f)


with open('CatBoost/results_model/multiple_shap_summary_sorted_CN.pkl', 'rb') as f:
    multiple_shap_summary_sorted_CatBoost = pickle.load(f)

with open('CatBoost/results_model/multiple_shap_values_CN.pkl', 'rb') as f:
    multiple_shap_values_CatBoost = pickle.load(f)


with open('ElasticNet/results_model/multiple_shap_summary_sorted_CN.pkl', 'rb') as f:
    multiple_shap_summary_sorted_ElasticNet = pickle.load(f)

with open('ElasticNet/results_model/multiple_shap_values_CN.pkl', 'rb') as f:
    multiple_shap_values_ElasticNet = pickle.load(f)


with open('KernelRidge/results_model/multiple_shap_summary_sorted_CN.pkl', 'rb') as f:
    multiple_shap_summary_sorted_KernelRidge = pickle.load(f)

with open('KernelRidge/results_model/multiple_shap_values_CN.pkl', 'rb') as f:
    multiple_shap_values_KernelRidge = pickle.load(f)


with open('KNN/results_model/multiple_shap_summary_sorted_CN.pkl', 'rb') as f:
    multiple_shap_summary_sorted_KNN = pickle.load(f)

with open('KNN/results_model/multiple_shap_values_CN.pkl', 'rb') as f:
    multiple_shap_values_KNN = pickle.load(f)


with open('Lasso/results_model/multiple_shap_summary_sorted_CN.pkl', 'rb') as f:
    multiple_shap_summary_sorted_Lasso = pickle.load(f)

with open('Lasso/results_model/multiple_shap_values_CN.pkl', 'rb') as f:
    multiple_shap_values_Lasso = pickle.load(f)


with open('MLP/results_model/multiple_shap_summary_sorted_CN.pkl', 'rb') as f:
    multiple_shap_summary_sorted_MLP = pickle.load(f)

with open('MLP/results_model/multiple_shap_values_CN.pkl', 'rb') as f:
    multiple_shap_values_MLP = pickle.load(f)


with open('Random_Forest/results_model/multiple_shap_summary_sorted_CN.pkl', 'rb') as f:
    multiple_shap_summary_sorted_RandomForest = pickle.load(f)

with open('Random_Forest/results_model/multiple_shap_values_CN.pkl', 'rb') as f:
    multiple_shap_values_RandomForest = pickle.load(f)


with open('SVR/results_model/multiple_shap_summary_sorted_CN.pkl', 'rb') as f:
    multiple_shap_summary_sorted_SVR = pickle.load(f)

with open('SVR/results_model/multiple_shap_values_CN.pkl', 'rb') as f:
    multiple_shap_values_SVR = pickle.load(f)


with open('XGBoost/results_model/multiple_shap_summary_sorted_CN.pkl', 'rb') as f:
    multiple_shap_summary_sorted_XGBoost = pickle.load(f)

with open('XGBoost/results_model/multiple_shap_values_CN.pkl', 'rb') as f:
    multiple_shap_values_XGBoost = pickle.load(f)


# Incluyendo Ridge
with open('Ridge/results_model/multiple_shap_summary_sorted_CN.pkl', 'rb') as f:
    multiple_shap_summary_sorted_Ridge = pickle.load(f)

with open('Ridge/results_model/multiple_shap_values_CN.pkl', 'rb') as f:
    multiple_shap_values_Ridge = pickle.load(f)


# Incluyendo BayesianRidge
with open('BayesianRidge/results_model/multiple_shap_summary_sorted_CN.pkl', 'rb') as f:
    multiple_shap_summary_sorted_BayesianRidge = pickle.load(f)

with open('BayesianRidge/results_model/multiple_shap_values_CN.pkl', 'rb') as f:
    multiple_shap_values_BayesianRidge = pickle.load(f)

# %%
multiple_shap_summary_sorted_Lasso
# Out:
# [('Low_subj_spec_RPD_OCC_left', 13447.095370078923),
#  ('High_subj_spec_EPP_OCC_left', 7039.885003721599),
#  ('Low_subj_spec_RPD_CING_right', 6037.485363315451),
#  ('Low_subj_spec_RPD_PARIET_left', 5790.006349336026),
#  ('High_subj_spec_RPD_OCC_left', 5240.840761764556),
#  ('Low_subj_spec_EPP_CING_left', 5114.648015096693),
#  ('Alpha2_canon_EPP_HPC_left', 4517.647981390074),
#  ('Low_subj_spec_EPP_HPC_left', 4213.979280752843),
#  ('Low_subj_spec_RPD_CING_left', 4105.66446143213),
#  ('High_subj_spec_RPD_CING_left', 3953.8683373832187),
#  ('Low_subj_spec_EPP_HPC_right', 3505.736065907141),
#  ('Low_subj_spec_EPP_PARIET_left', 3493.252760001082),
#  ('Low_subj_spec_RPD_PARIET_right', 3244.4535717823915),
#  ('IAF_OCC_right', 3110.009270430868),
#  ('High_subj_spec_RPD_HPC_right', 3014.9917669747097),
#  ('Alpha2_canon_EPP_OCC_left', 3009.8410166347203),
#  ('Alpha2_canon_RPD_OCC_left', 2928.444705246186),
#  ('TF_MFG_right', 2777.675330330857),
# ...

# %%
# Definir los diccionarios de SHAP para cada grupo
shap_summary_dict_BaggedKNN = dict(multiple_shap_summary_sorted_BaggedKNN)
shap_summary_dict_CatBoost = dict(multiple_shap_summary_sorted_CatBoost)
shap_summary_dict_ElasticNet = dict(multiple_shap_summary_sorted_ElasticNet)
shap_summary_dict_KernelRidge = dict(multiple_shap_summary_sorted_KernelRidge)
shap_summary_dict_KNN = dict(multiple_shap_summary_sorted_KNN)
shap_summary_dict_Lasso = dict(multiple_shap_summary_sorted_Lasso)
shap_summary_dict_MLP = dict(multiple_shap_summary_sorted_MLP)
shap_summary_dict_RandomForest = dict(multiple_shap_summary_sorted_RandomForest)
shap_summary_dict_SVR = dict(multiple_shap_summary_sorted_SVR)
shap_summary_dict_XGBoost = dict(multiple_shap_summary_sorted_XGBoost)

# Incluir Ridge y BayesianRidge
shap_summary_dict_Ridge = dict(multiple_shap_summary_sorted_Ridge)
shap_summary_dict_BayesianRidge = dict(multiple_shap_summary_sorted_BayesianRidge)

# Diccionario con todos los modelos
grupos_shap = {
    'BaggedKNN': shap_summary_dict_BaggedKNN,
    'CatBoost': shap_summary_dict_CatBoost,
    'ElasticNet': shap_summary_dict_ElasticNet,
    'KernelRidge': shap_summary_dict_KernelRidge,
    'KNN': shap_summary_dict_KNN,
    'Lasso': shap_summary_dict_Lasso,
    'MLP': shap_summary_dict_MLP,
    'RandomForest': shap_summary_dict_RandomForest,
    'SVR': shap_summary_dict_SVR,
    'XGBoost': shap_summary_dict_XGBoost,
    'Ridge': shap_summary_dict_Ridge,
    'BayesianRidge': shap_summary_dict_BayesianRidge
}

# %%
grupos_shap
# Out:
# {'BaggedKNN': {'IAF_OCC_right': 1428.692536129636,
#   'IAF_OCC_left': 1333.2190458561615,
#   'TF_MFG_right': 687.4016899143455,
#   'Low_subj_spec_EPP_PARIET_right': 672.1393170729858,
#   'Low_subj_spec_EPP_OCC_right': 645.80549332391,
#   'Low_subj_spec_EPP_PARIET_left': 634.2633210344744,
#   'Low_subj_spec_RPD_CING_right': 632.889757516207,
#   'Alpha2_canon_RPD_CING_right': 596.2272194600729,
#   'IAF_HPC_left': 579.4420053270869,
#   'IAF_INS_left': 578.26494812049,
#   'High_subj_spec_RPD_CING_right': 572.5654231963296,
#   'High_subj_spec_EPP_CING_right': 565.8440465859056,
#   'TF_ORB_right': 530.7755087070691,
#   'Low_subj_spec_RPD_CING_left': 499.03957481410333,
#   'Alpha2_canon_RPD_CING_left': 489.342895553152,
#   'Low_subj_spec_RPD_HPC_left': 480.08631798725264,
#   'Low_subj_spec_RPD_HPC_right': 471.02329492070834,
#   'Alpha2_canon_RPD_PARIET_right': 461.3431694237756,
#   'Alpha2_canon_EPP_PARIET_right': 459.13974094093624,
# ...

# %%
import numpy as np

# Función para escalar los valores SHAP sin afectar el 0
def escalar_shap_personalizado(shap_dict):
    valores = np.array(list(shap_dict.values()))
    max_valor = valores.max()  # Encontrar el valor máximo

    if max_valor == 0:
        return shap_dict  # Evitar división por 0 si todos los valores son 0

    # Escalar los valores dividiendo por el máximo
    valores_escalados = valores / max_valor  
    return dict(zip(shap_dict.keys(), valores_escalados))

# Aplicar el escalado a cada modelo
grupos_shap_escalados = {
    modelo: escalar_shap_personalizado(shap_dict)
    for modelo, shap_dict in grupos_shap.items()
}

# Ejemplo de salida escalada para BaggedKNN
print(grupos_shap_escalados['BaggedKNN'])
# Out:
# {'IAF_OCC_right': 1.0, 'IAF_OCC_left': 0.9331742219833286, 'TF_MFG_right': 0.48114039412324083, 'Low_subj_spec_EPP_PARIET_right': 0.47045763876798025, 'Low_subj_spec_EPP_OCC_right': 0.45202552473145363, 'Low_subj_spec_EPP_PARIET_left': 0.4439466890144955, 'Low_subj_spec_RPD_CING_right': 0.4429852760557715, 'Alpha2_canon_RPD_CING_right': 0.4173236748861777, 'IAF_HPC_left': 0.40557502098863757, 'IAF_INS_left': 0.4047511507878555, 'High_subj_spec_RPD_CING_right': 0.4007618215374903, 'High_subj_spec_EPP_CING_right': 0.396057256741042, 'TF_ORB_right': 0.371511361111295, 'Low_subj_spec_RPD_CING_left': 0.3492980905226915, 'Alpha2_canon_RPD_CING_left': 0.34251099041841027, 'Low_subj_spec_RPD_HPC_left': 0.3360319353860548, 'Low_subj_spec_RPD_HPC_right': 0.32968835701817434, 'Alpha2_canon_RPD_PARIET_right': 0.32291284356644423, 'Alpha2_canon_EPP_PARIET_right': 0.3213705743747758, 'Alpha2_canon_RPD_HPC_right': 0.320307132942799, 'Alpha2_canon_EPP_HPC_right': 0.3151050310234818, 'High_subj_spec_
# ...

# %%
print(grupos_shap_escalados['ElasticNet'])
# Out:
# {'Low_subj_spec_RPD_OCC_left': 1.0, 'High_subj_spec_RPD_OCC_left': 0.47783127480153315, 'Low_subj_spec_RPD_PARIET_left': 0.45662815334244766, 'High_subj_spec_EPP_OCC_left': 0.4508558667097918, 'Low_subj_spec_EPP_CING_left': 0.4138455384309361, 'Low_subj_spec_RPD_CING_right': 0.39653585459669205, 'Low_subj_spec_RPD_CING_left': 0.3693670823083634, 'Low_subj_spec_EPP_HPC_left': 0.36265809498063994, 'Low_subj_spec_RPD_PARIET_right': 0.318964740371338, 'Low_subj_spec_EPP_HPC_right': 0.3050444090000591, 'High_subj_spec_EPP_CING_left': 0.2887744472061588, 'High_subj_spec_RPD_CING_left': 0.27416661113778257, 'Low_subj_spec_EPP_PARIET_left': 0.2657739866218612, 'Alpha2_canon_RPD_OCC_left': 0.24191915924399263, 'Alpha2_canon_EPP_OCC_left': 0.2302681092566938, 'IAF_OCC_right': 0.2280618456293654, 'Alpha2_canon_EPP_HPC_left': 0.21774934843646906, 'TF_MFG_right': 0.2161277801292715, 'IAF_INS_right': 0.214175174474129, 'Alpha2_canon_RPD_HPC_left': 0.21126545676873568, 'High_subj_spec_RPD_PARIET_ri
# ...

# %%
print(grupos_shap_escalados['Lasso'])
# Out:
# {'Low_subj_spec_RPD_OCC_left': 1.0, 'High_subj_spec_EPP_OCC_left': 0.523524583560701, 'Low_subj_spec_RPD_CING_right': 0.4489806309211902, 'Low_subj_spec_RPD_PARIET_left': 0.43057672976867145, 'High_subj_spec_RPD_OCC_left': 0.38973775507132413, 'Low_subj_spec_EPP_CING_left': 0.3803533680944418, 'Alpha2_canon_EPP_HPC_left': 0.33595716078895926, 'Low_subj_spec_EPP_HPC_left': 0.31337468537103935, 'Low_subj_spec_RPD_CING_left': 0.305319799439188, 'High_subj_spec_RPD_CING_left': 0.2940314044459709, 'Low_subj_spec_EPP_HPC_right': 0.2607058230365302, 'Low_subj_spec_EPP_PARIET_left': 0.2597774957240137, 'Low_subj_spec_RPD_PARIET_right': 0.2412754191512326, 'IAF_OCC_right': 0.23127740116656992, 'High_subj_spec_RPD_HPC_right': 0.22421137680657457, 'Alpha2_canon_EPP_OCC_left': 0.22382833867095978, 'Alpha2_canon_RPD_OCC_left': 0.21777526109930448, 'TF_MFG_right': 0.2065632208210147, 'IAF_INS_right': 0.1994407547262194, 'Low_subj_spec_EPP_OCC_left': 0.18186813562627496, 'IAF_IFG_right': 0.16686085
# ...

# %%
# Convertir los diccionarios a un DataFrame
df_shap = pd.DataFrame(grupos_shap_escalados).fillna(0)  # Rellenar valores faltantes con 0

# %%
# Calcular la correlación de Spearman
correlation_matrix = df_shap.corr(method='spearman')

# Mostrar la matriz de correlación
print(correlation_matrix)
# Out:
#                BaggedKNN  CatBoost  ElasticNet  KernelRidge       KNN  \
# BaggedKNN       1.000000  0.813364    0.045694     0.342080  0.966139
# CatBoost        0.813364  1.000000    0.282044     0.419287  0.872403
# ElasticNet      0.045694  0.282044    1.000000     0.403209  0.107949
# KernelRidge     0.342080  0.419287    0.403209     1.000000  0.343463
# KNN             0.966139  0.872403    0.107949     0.343463  1.000000
# Lasso          -0.001672  0.220336    0.909576     0.353688  0.049778
# MLP             0.239051  0.321950    0.357901     0.500289  0.220625
# RandomForest    0.664641  0.850601    0.413724     0.479291  0.717313
# SVR             0.457554  0.371471    0.230369     0.721847  0.415911
# XGBoost         0.597981  0.770500    0.433951     0.554376  0.637758
# Ridge           0.044054  0.283812    0.997267     0.398418  0.104412
# BayesianRidge   0.150267  0.267959    0.557978     0.661779  0.151521
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlación de Spearman entre Modelos")
plt.show()

# %%
correlation_matrix_pearson = df_shap.corr(method='pearson')
print(correlation_matrix_pearson)
# Out:
#                BaggedKNN  CatBoost  ElasticNet  KernelRidge       KNN  \
# BaggedKNN       1.000000  0.829612    0.028824     0.502406  0.977323
# CatBoost        0.829612  1.000000    0.070690     0.577791  0.876447
# ElasticNet      0.028824  0.070690    1.000000     0.435645  0.056987
# KernelRidge     0.502406  0.577791    0.435645     1.000000  0.502963
# KNN             0.977323  0.876447    0.056987     0.502963  1.000000
# Lasso           0.033215  0.069986    0.960976     0.441762  0.051822
# MLP             0.345052  0.350902    0.404268     0.747184  0.321326
# RandomForest    0.695243  0.899495    0.179957     0.632265  0.735814
# SVR             0.797196  0.734871    0.190261     0.767378  0.757192
# XGBoost         0.696554  0.881394    0.202798     0.664212  0.736905
# Ridge           0.027165  0.068488    0.999370     0.432532  0.055331
# BayesianRidge   0.467178  0.511617    0.461710     0.815939  0.432566
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_pearson, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlación de Pearson entre Modelos")
plt.show()

# %%
from scipy.spatial.distance import pdist, squareform

# Calcular distancia del coseno (1 - similitud coseno)
cosine_dist = pdist(df_shap.T, metric='cosine')
cosine_sim = 1 - squareform(cosine_dist)  # Convertir distancia a similitud

# Convertir en DataFrame
cosine_df = pd.DataFrame(cosine_sim, index=df_shap.columns, columns=df_shap.columns)

# Graficar
plt.figure(figsize=(10,8))
sns.heatmap(cosine_df, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Similitud del Coseno entre Modelos (SHAP)")
plt.show()

# %%
def calcular_suma_shap_por_grupo(shap_dict):
    """
    Calcula la suma de los valores SHAP por subregión para un grupo dado.
    
    Parámetros:
    shap_dict (dict): Diccionario que contiene los valores SHAP para cada grupo.

    Retorna:
    dict: Diccionario con la suma de los valores SHAP por subregión.
    """
    # Definir las regiones como listas
    OCC_left = [
        'Low_subj_spec_EPP_OCC_left', 'IAF_OCC_left', 'Alpha2_canon_EPP_OCC_left', 
        'Alpha2_canon_RPD_OCC_left', 'High_subj_spec_EPP_OCC_left', 'High_subj_spec_RPD_OCC_left'
    ]

    OCC_right = [
        'Low_subj_spec_EPP_OCC_right', 'IAF_OCC_right', 'Alpha2_canon_EPP_OCC_right', 
        'Alpha2_canon_RPD_OCC_right', 'High_subj_spec_EPP_OCC_right', 'High_subj_spec_RPD_OCC_right'
    ]

    HPC_left = [
        'Low_subj_spec_RPD_HPC_left', 'IAF_HPC_left', 'Low_subj_spec_EPP_HPC_left', 
        'TF_HPC_left', 'Alpha2_canon_EPP_HPC_left', 'Alpha2_canon_RPD_HPC_left', 
        'High_subj_spec_EPP_HPC_left', 'High_subj_spec_RPD_HPC_left'
    ]

    HPC_right = [
        'Low_subj_spec_RPD_HPC_right', 'IAF_HPC_right', 'Alpha2_canon_EPP_HPC_right', 
        'Alpha2_canon_RPD_HPC_right', 'High_subj_spec_EPP_HPC_right', 'High_subj_spec_RPD_HPC_right', 
        'TF_HPC_right'
    ]

    PARIET_left = [
        'Alpha2_canon_EPP_PARIET_left', 'Alpha2_canon_RPD_PARIET_left', 
        'High_subj_spec_EPP_PARIET_left', 'Low_subj_spec_EPP_PARIET_left', 
        'Low_subj_spec_RPD_PARIET_left'
    ]

    PARIET_right = [
        'Low_subj_spec_RPD_PARIET_right', 'Alpha2_canon_EPP_PARIET_right', 
        'Alpha2_canon_RPD_PARIET_right', 'High_subj_spec_EPP_PARIET_right', 
        'Low_subj_spec_EPP_PARIET_right', 'High_subj_spec_RPD_PARIET_right'
    ]

    CING_left = [
        'Low_subj_spec_EPP_CING_left', 'Alpha2_canon_RPD_CING_left', 
        'High_subj_spec_EPP_CING_left', 'High_subj_spec_RPD_CING_left', 
        'Low_subj_spec_RPD_CING_left'
    ]

    CING_right = [
        'Low_subj_spec_EPP_CING_right', 'Alpha2_canon_RPD_CING_right', 
        'High_subj_spec_EPP_CING_right', 'High_subj_spec_RPD_CING_right', 
        'Low_subj_spec_RPD_CING_right'
    ]

    ORB_left = ['IAF_ORB_left', 'TF_ORB_left']
    ORB_right = ['IAF_ORB_right', 'TF_ORB_right']

    INS_left = ['IAF_INS_left', 'TF_INS_left']
    INS_right = ['IAF_INS_right', 'TF_INS_right']

    IFG_left = ['TF_IFG_left', 'IAF_IFG_left']
    IFG_right = ['TF_IFG_right', 'IAF_IFG_right']

    SFG_left = ['TF_SFG_left', 'IAF_SFG_left']
    SFG_right = ['TF_SFG_right', 'IAF_SFG_right']

    MFG_left = ['IAF_MFG_left', 'TF_MFG_left']
    MFG_right = ['IAF_MFG_right', 'TF_MFG_right']

    # Lista de regiones
    regiones = [
        OCC_left, OCC_right, HPC_left, HPC_right, 
        PARIET_left, PARIET_right, CING_left, CING_right, 
        ORB_left, ORB_right, INS_left, INS_right, 
        IFG_left, IFG_right, SFG_left, SFG_right, 
        MFG_left, MFG_right
    ]

    # Nombres de las regiones
    nombres_regiones = [
        'OCC_left', 'OCC_right', 'HPC_left', 'HPC_right', 
        'PARIET_left', 'PARIET_right', 'CING_left', 'CING_right', 
        'ORB_left', 'ORB_right', 'INS_left', 'INS_right', 
        'IFG_left', 'IFG_right', 'SFG_left', 'SFG_right', 
        'MFG_left', 'MFG_right'
    ]
    
    # Diccionario para almacenar las sumas de SHAP por subregión
    shap_sumas_subregion = {}

    # Iterar sobre cada subregión y sumar los valores SHAP
    for nombre, subregion in zip(nombres_regiones, regiones):
        suma_shap = 0
        for elemento in subregion:
            if elemento in shap_dict:
                suma_shap += shap_dict[elemento]
        
        # Guardar la suma en el diccionario con el nombre de la subregión
        shap_sumas_subregion[nombre] = suma_shap

    return shap_sumas_subregion

# Definir los diccionarios de SHAP para cada grupo
shap_summary_dict_BaggedKNN = dict(multiple_shap_summary_sorted_BaggedKNN)
shap_summary_dict_CatBoost = dict(multiple_shap_summary_sorted_CatBoost)
shap_summary_dict_ElasticNet = dict(multiple_shap_summary_sorted_ElasticNet)
shap_summary_dict_KernelRidge = dict(multiple_shap_summary_sorted_KernelRidge)
shap_summary_dict_KNN = dict(multiple_shap_summary_sorted_KNN)
shap_summary_dict_Lasso = dict(multiple_shap_summary_sorted_Lasso)
shap_summary_dict_MLP = dict(multiple_shap_summary_sorted_MLP)
shap_summary_dict_RandomForest = dict(multiple_shap_summary_sorted_RandomForest)
shap_summary_dict_SVR = dict(multiple_shap_summary_sorted_SVR)
shap_summary_dict_XGBoost = dict(multiple_shap_summary_sorted_XGBoost)

# Incluir Ridge y BayesianRidge
shap_summary_dict_Ridge = dict(multiple_shap_summary_sorted_Ridge)
shap_summary_dict_BayesianRidge = dict(multiple_shap_summary_sorted_BayesianRidge)

# Diccionario con todos los modelos
grupos_shap = {
    'BaggedKNN': shap_summary_dict_BaggedKNN,
    'CatBoost': shap_summary_dict_CatBoost,
    'ElasticNet': shap_summary_dict_ElasticNet,
    'KernelRidge': shap_summary_dict_KernelRidge,
    'KNN': shap_summary_dict_KNN,
    'Lasso': shap_summary_dict_Lasso,
    'MLP': shap_summary_dict_MLP,
    'RandomForest': shap_summary_dict_RandomForest,
    'SVR': shap_summary_dict_SVR,
    'XGBoost': shap_summary_dict_XGBoost,
    'Ridge': shap_summary_dict_Ridge,
    'BayesianRidge': shap_summary_dict_BayesianRidge
}

# Iterar sobre cada grupo y calcular la suma de SHAP por subregión
resultados_suma_shap_region = {}
for grupo, shap_dict in grupos_shap.items():
    resultados_suma_shap_region[grupo] = calcular_suma_shap_por_grupo(shap_dict)

# Imprimir resultados
for grupo, sumas in resultados_suma_shap_region.items():
    print(f"Suma de SHAP por subregión para el grupo {grupo}:")
    for subregion, suma in sumas.items():
        print(f"  {subregion}: {suma}")
    print("\n")
# Out:
# Suma de SHAP por subregión para el grupo BaggedKNN:
#   OCC_left: 2539.3632301022303
#   OCC_right: 2748.3562254259514
#   HPC_left: 3077.1241878504266
#   HPC_right: 2807.9119725528058
#   PARIET_left: 2126.0537222056764
#   PARIET_right: 2736.5318337470126
#   CING_left: 2127.22569013705
#   CING_right: 2749.0879940192362
#   ORB_left: 615.3545371668254
#   ORB_right: 781.5383219992925
#   INS_left: 955.0259159376927
#   INS_right: 702.493842731579
#   IFG_left: 495.15598074985667
#   IFG_right: 644.8343626126427
#   SFG_left: 409.78707257316256
#   SFG_right: 550.5471653954329
#   MFG_left: 624.6056961133262
#   MFG_right: 919.7381355019063
#
#
# Suma de SHAP por subregión para el grupo CatBoost:
#   OCC_left: 3373.6642904540126
#   OCC_right: 4109.215991860118
#   HPC_left: 3616.586883546735
#   HPC_right: 1809.5280692560561
#   PARIET_left: 2580.484176706062
#   PARIET_right: 2273.2781738504523
#   CING_left: 1687.1230730248876
#   CING_right: 4319.051426236576
# ...

# %%
resultados_suma_shap_region
# Out:
# {'BaggedKNN': {'OCC_left': 2539.3632301022303,
#   'OCC_right': 2748.3562254259514,
#   'HPC_left': 3077.1241878504266,
#   'HPC_right': 2807.9119725528058,
#   'PARIET_left': 2126.0537222056764,
#   'PARIET_right': 2736.5318337470126,
#   'CING_left': 2127.22569013705,
#   'CING_right': 2749.0879940192362,
#   'ORB_left': 615.3545371668254,
#   'ORB_right': 781.5383219992925,
#   'INS_left': 955.0259159376927,
#   'INS_right': 702.493842731579,
#   'IFG_left': 495.15598074985667,
#   'IFG_right': 644.8343626126427,
#   'SFG_left': 409.78707257316256,
#   'SFG_right': 550.5471653954329,
#   'MFG_left': 624.6056961133262,
#   'MFG_right': 919.7381355019063},
#  'CatBoost': {'OCC_left': 3373.6642904540126,
#   'OCC_right': 4109.215991860118,
#   'HPC_left': 3616.586883546735,
#   'HPC_right': 1809.5280692560561,
#   'PARIET_left': 2580.484176706062,
#   'PARIET_right': 2273.2781738504523,
#   'CING_left': 1687.1230730248876,
#   'CING_right': 4319.051426236576,
# ...

# %%
df_shap_region = pd.DataFrame(resultados_suma_shap_region).fillna(0)  # Rellenar valores faltantes con 0

# %%
df_shap_region
# Out:
#                 BaggedKNN     CatBoost    ElasticNet  KernelRidge  \
# OCC_left      2539.363230  3373.664290  22404.624144  5874.360728
# OCC_right     2748.356225  4109.215992   9953.300476  6071.585566
# HPC_left      3077.124188  3616.586884  13980.762536  6540.002791
# HPC_right     2807.911973  1809.528069   7829.177528  4733.650853
# PARIET_left   2126.053722  2580.484177  14193.609209  4692.897188
# PARIET_right  2736.531834  2273.278174  11470.600062  4398.072439
# CING_left     2127.225690  1687.123073  19808.723880  5063.271250
# CING_right    2749.087994  4319.051426   9795.578781  9467.275822
# ORB_left       615.354537   173.962430   1943.490995  1673.889610
# ORB_right      781.538322   213.881292   1802.392132   997.101657
# INS_left       955.025916   556.991291   2164.605282  1631.270963
# INS_right      702.493843   273.739376   2865.380437  2054.857935
# IFG_left       495.155981    97.576006    970.879647  1089.283086
# ...

# %%
df_shap_region = pd.DataFrame(resultados_suma_shap_region).fillna(0)  # Rellenar valores faltantes con 0

# Calcular la correlación de Spearman
correlation_matrix_region = df_shap_region.corr(method='spearman')

# Mostrar la matriz de correlación
print(correlation_matrix_region)
# Out:
#                BaggedKNN  CatBoost  ElasticNet  KernelRidge       KNN  \
# BaggedKNN       1.000000  0.925697    0.805986     0.876161  0.993808
# CatBoost        0.925697  1.000000    0.824561     0.915377  0.923633
# ElasticNet      0.805986  0.824561    1.000000     0.830753  0.816305
# KernelRidge     0.876161  0.915377    0.830753     1.000000  0.882353
# KNN             0.993808  0.923633    0.816305     0.882353  1.000000
# Lasso           0.808050  0.832817    0.997936     0.841073  0.814241
# MLP             0.803922  0.867905    0.902993     0.882353  0.814241
# RandomForest    0.915377  0.991744    0.824561     0.927761  0.915377
# SVR             0.874097  0.874097    0.781218     0.872033  0.888545
# XGBoost         0.902993  0.989680    0.820433     0.917441  0.902993
# Ridge           0.805986  0.824561    1.000000     0.830753  0.816305
# BayesianRidge   0.797730  0.872033    0.909185     0.888545  0.801858
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_region, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlación de Spearman entre Modelos Subregiones Cerebrales")
plt.show()
