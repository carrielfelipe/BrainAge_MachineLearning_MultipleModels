# %%
path=  'C:/Users/felip/OneDrive - Universidad Técnica Federico Santa María/Documentos/Brain/'
#import sys
#sys.path.append(path) 
path_=  'C:/Users/felip/OneDrive - Universidad Técnica Federico Santa María/Documentos/Brain/Brain_Age_Clock/Base_Models'
import sys
sys.path.append(path_)

# %%
#72 features
features = ['Alpha2_canon_EPP_HPC_left', 'Alpha2_canon_EPP_HPC_right', 'Alpha2_canon_EPP_PARIET_left', 'Alpha2_canon_EPP_PARIET_right', 'Alpha2_canon_EPP_OCC_left', 'Alpha2_canon_EPP_OCC_right', 'Alpha2_canon_RPD_HPC_left', 'Alpha2_canon_RPD_HPC_right', 'Alpha2_canon_RPD_CING_left', 'Alpha2_canon_RPD_CING_right', 'Alpha2_canon_RPD_PARIET_left', 'Alpha2_canon_RPD_PARIET_right', 'Alpha2_canon_RPD_OCC_left', 'Alpha2_canon_RPD_OCC_right', 'High_subj_spec_EPP_HPC_left', 'High_subj_spec_EPP_HPC_right', 'High_subj_spec_EPP_CING_left', 'High_subj_spec_EPP_CING_right', 'High_subj_spec_EPP_PARIET_left', 'High_subj_spec_EPP_PARIET_right', 'High_subj_spec_EPP_OCC_left', 'High_subj_spec_EPP_OCC_right', 'High_subj_spec_RPD_HPC_left', 'High_subj_spec_RPD_HPC_right', 'High_subj_spec_RPD_CING_left', 'High_subj_spec_RPD_CING_right', 'High_subj_spec_RPD_PARIET_left', 'High_subj_spec_RPD_PARIET_right', 'High_subj_spec_RPD_OCC_left', 'High_subj_spec_RPD_OCC_right', 'Low_subj_spec_EPP_HPC_left', 'Low_subj_spec_EPP_HPC_right', 'Low_subj_spec_EPP_CING_left', 'Low_subj_spec_EPP_CING_right', 'Low_subj_spec_EPP_PARIET_left', 'Low_subj_spec_EPP_PARIET_right', 'Low_subj_spec_EPP_OCC_left', 'Low_subj_spec_EPP_OCC_right', 'Low_subj_spec_RPD_HPC_left', 'Low_subj_spec_RPD_HPC_right', 'Low_subj_spec_RPD_CING_left', 'Low_subj_spec_RPD_CING_right', 'Low_subj_spec_RPD_PARIET_left', 'Low_subj_spec_RPD_PARIET_right', 'Low_subj_spec_RPD_OCC_left', 'Low_subj_spec_RPD_OCC_right', 'TF_ORB_left', 'TF_ORB_right', 'TF_IFG_left', 'TF_IFG_right', 'TF_MFG_left', 'TF_MFG_right', 'TF_SFG_left', 'TF_SFG_right', 'TF_HPC_left', 'TF_HPC_right', 'TF_INS_left', 'TF_INS_right', 'IAF_ORB_left', 'IAF_ORB_right', 'IAF_IFG_left', 'IAF_IFG_right', 'IAF_MFG_left', 'IAF_MFG_right', 'IAF_SFG_left', 'IAF_SFG_right', 'IAF_HPC_left', 'IAF_HPC_right', 'IAF_INS_left', 'IAF_INS_right', 'IAF_OCC_left', 'IAF_OCC_right']

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import pickle

file_path_CN = f'{path}BrainAge_MachineLearning_MultipleModels/Data/CN_freq.xlsx'

df_CN = pd.read_excel(file_path_CN)


df_CN_filtrado = df_CN[(df_CN['Age'] >=20) & (df_CN['Age'] <= 90)].reset_index(drop=True)


X_CN = df_CN_filtrado[features]
y_CN = df_CN_filtrado["Age"]
ID_CN = df_CN_filtrado["ID_unique"]

#Scaler segun algoritmo
scaler = StandardScaler()
scaler.fit(X_CN)

X_CN_scaled = scaler.transform(X_CN)

X_CN_scaled = pd.DataFrame(X_CN_scaled, columns=X_CN.columns)

df_concatenado_CN = pd.concat([X_CN, y_CN, ID_CN], axis=1, ignore_index=False)

# %%
df_CN['Country_ID']
# Out:
# 0       CUB_123_2_sub-10001
# 1       CUB_123_2_sub-10004
# 2       CUB_123_2_sub-10005
# 3       CUB_123_2_sub-10006
# 4       CUB_123_2_sub-10007
#                 ...
# 1379      CHI_TAK_sub-100017
# 1380      CHI_TAK_sub-100018
# 1381      CHI_TAK_sub-100019
# 1382      CHI_TAK_sub-100020
# 1383      CHI_TAK_sub-100021
# Name: Country_ID, Length: 1384, dtype: object

# %%
paises = df_CN['Country_ID'].str.extract(r'^([A-Z]+)_')[0].unique()
print(paises)
# Out:
# ['CUB' 'ARG' 'CHI' 'TUR' 'IRL' 'COL' 'BRA' 'GRE' 'ITA' 'UK' 'CALI']

# %%
df_CN_filtrado
# Out:
#       Unnamed: 0  Delta_canon_EPP_ORB_left  Delta_canon_EPP_ORB_right  \
# 0              0                  0.059161                   0.070466
# 1              1                  0.054096                   0.047097
# 2              2                  0.059660                   0.051740
# 3              3                  0.058654                   0.056826
# 4              5                  0.045243                   0.072727
# ...          ...                       ...                        ...
# 1318        1444                  0.035464                   0.035469
# 1319        1445                  0.054815                   0.048826
# 1320        1446                  0.044759                   0.052309
# 1321        1447                  0.059905                   0.064894
# 1322        1448                  0.032594                   0.038136
#
#       Delta_canon_EPP_IFG_left  Delta_canon_EPP_IFG_right  \
# 0                     0.051849                   0.049289
# 1                     0.056917                   0.044670
# 2                     0.061596                   0.052308
# 3                     0.060448                   0.056367
# 4                     0.047176                   0.051046
# ...                        ...                        ...
# 1318                  0.035834                   0.034404
# 1319                  0.049235                   0.049774
# 1320                  0.042457                   0.046901
# 1321                  0.052238                   0.051449
# 1322                  0.030101                   0.036569
#
#       Delta_canon_EPP_MFG_left  Delta_canon_EPP_MFG_right  \
# 0                     0.049934                   0.047389
# 1                     0.055201                   0.042544
# 2                     0.061998                   0.046384
# 3                     0.068132                   0.053792
# 4                     0.044083                   0.038109
# ...                        ...                        ...
# 1318                  0.030824                   0.030423
# 1319                  0.044013                   0.046808
# 1320                  0.038112                   0.037699
# 1321                  0.039586                   0.041117
# 1322                  0.035927                   0.034773
#
#       Delta_canon_EPP_SFG_left  Delta_canon_EPP_SFG_right  \
# 0                     0.049015                   0.047568
# 1                     0.048499                   0.039344
# 2                     0.053836                   0.056489
# 3                     0.067543                   0.045742
# 4                     0.039820                   0.039903
# ...                        ...                        ...
# 1318                  0.031417                   0.031326
# 1319                  0.044252                   0.046730
# 1320                  0.038526                   0.039239
# 1321                  0.042107                   0.041310
# 1322                  0.033520                   0.034468
#
#       Delta_canon_EPP_HPC_left  ...  IAF_OCC_right             Country_ID  \
# 0                     0.041415  ...       8.791667  CUB_123_2_sub-10001
# 1                     0.041028  ...      11.500000  CUB_123_2_sub-10004
# 2                     0.060980  ...      10.166667  CUB_123_2_sub-10005
# 3                     0.058767  ...      11.083333  CUB_123_2_sub-10006
# 4                     0.042739  ...      10.250000  CUB_123_2_sub-10008
# ...                        ...  ...            ...                    ...
# 1318                  0.038548  ...       9.041667    CHI_TAK_sub-100017
# 1319                  0.053651  ...       9.625000    CHI_TAK_sub-100018
# 1320                  0.049349  ...       8.000000    CHI_TAK_sub-100019
# 1321                  0.050399  ...       9.708333    CHI_TAK_sub-100020
# 1322                  0.034192  ...       8.833333    CHI_TAK_sub-100021
#
#        Age  Sex  Educ  MMSE     HDI   GINI        ODQ  ID_unique
# 0     33.0  1.0  19.0  30.0  0.7578  40.70  99.282421          0
# 1     57.0  2.0  13.0   NaN  0.7578  40.70  99.739738          1
# 2     32.0  1.0  10.0   NaN  0.7578  40.70  99.361739          2
# 3     21.0  1.0  13.0   NaN  0.7578  40.70  99.561273          3
# 4     36.0  1.0  19.0  30.0  0.7578  40.70  99.374132          5
# ...    ...  ...   ...   ...     ...    ...        ...        ...
# 1318  57.0  2.0  17.0  30.0  0.8550  44.92  99.599221       1379
# 1319  48.0  2.0  17.0  28.0  0.8550  44.92  99.675799       1380
# 1320  57.0  2.0  17.0  29.0  0.8550  44.92  99.641446       1381
# 1321  69.0  2.0  12.0  30.0  0.8550  44.92  98.420503       1382
# 1322  64.0  2.0  22.0  30.0  0.8550  44.92        NaN       1383
#
# [1323 rows x 228 columns]

# %%
# Extraer el prefijo de Country_ID
df_CN['Country_code'] = df_CN['Country_ID'].str.extract(r'^([A-Z]+)_')[0]

# Mapa de códigos a nombres de países
codigo_a_pais = {
    'CUB': 'Cuba',
    'ARG': 'Argentina',
    'CHI': 'Chile',
    'TUR': 'Turquia',
    'IRL': 'Irlanda',
    'COL': 'Colombia',
    'CALI': 'Colombia',
    'BRA': 'Brasil',
    'GRE': 'Grecia',
    'ITA': 'Italia',
    'UK': 'Reino Unido'
}

# Aplicar el mapeo
df_CN['Country_unique'] = df_CN['Country_code'].map(codigo_a_pais)

# %%
pais_a_region = {
    'Cuba': 'Cuba',
    'Argentina': 'America',
    'Chile': 'America',
    'Colombia': 'America',
    'Brasil': 'America',
    'Turquia': 'Turquia',
    'Irlanda': 'Europa',
    'Grecia': 'Europa',
    'Italia': 'Europa',
    'Reino Unido': 'Europa'
}

df_CN['Region'] = df_CN['Country_unique'].map(pais_a_region)

# %%
df_CN.drop(columns=['Country_code'], inplace=True)

# %%
df_CN
# Out:
#       Unnamed: 0  Delta_canon_EPP_ORB_left  Delta_canon_EPP_ORB_right  \
# 0              0                  0.059161                   0.070466
# 1              1                  0.054096                   0.047097
# 2              2                  0.059660                   0.051740
# 3              3                  0.058654                   0.056826
# 4              4                  0.043061                   0.042042
# ...          ...                       ...                        ...
# 1379        1444                  0.035464                   0.035469
# 1380        1445                  0.054815                   0.048826
# 1381        1446                  0.044759                   0.052309
# 1382        1447                  0.059905                   0.064894
# 1383        1448                  0.032594                   0.038136
#
#       Delta_canon_EPP_IFG_left  Delta_canon_EPP_IFG_right  \
# 0                     0.051849                   0.049289
# 1                     0.056917                   0.044670
# 2                     0.061596                   0.052308
# 3                     0.060448                   0.056367
# 4                     0.045694                   0.039943
# ...                        ...                        ...
# 1379                  0.035834                   0.034404
# 1380                  0.049235                   0.049774
# 1381                  0.042457                   0.046901
# 1382                  0.052238                   0.051449
# 1383                  0.030101                   0.036569
#
#       Delta_canon_EPP_MFG_left  Delta_canon_EPP_MFG_right  \
# 0                     0.049934                   0.047389
# 1                     0.055201                   0.042544
# 2                     0.061998                   0.046384
# 3                     0.068132                   0.053792
# 4                     0.045708                   0.036764
# ...                        ...                        ...
# 1379                  0.030824                   0.030423
# 1380                  0.044013                   0.046808
# 1381                  0.038112                   0.037699
# 1382                  0.039586                   0.041117
# 1383                  0.035927                   0.034773
#
#       Delta_canon_EPP_SFG_left  Delta_canon_EPP_SFG_right  \
# 0                     0.049015                   0.047568
# 1                     0.048499                   0.039344
# 2                     0.053836                   0.056489
# 3                     0.067543                   0.045742
# 4                     0.039002                   0.036255
# ...                        ...                        ...
# 1379                  0.031417                   0.031326
# 1380                  0.044252                   0.046730
# 1381                  0.038526                   0.039239
# 1382                  0.042107                   0.041310
# 1383                  0.033520                   0.034468
#
#       Delta_canon_EPP_HPC_left  ...   Age  Sex  Educ  MMSE     HDI   GINI  \
# 0                     0.041415  ...  33.0  1.0  19.0  30.0  0.7578  40.70
# 1                     0.041028  ...  57.0  2.0  13.0   NaN  0.7578  40.70
# 2                     0.060980  ...  32.0  1.0  10.0   NaN  0.7578  40.70
# 3                     0.058767  ...  21.0  1.0  13.0   NaN  0.7578  40.70
# 4                     0.044407  ...  19.0  1.0  13.0  30.0  0.7578  40.70
# ...                        ...  ...   ...  ...   ...   ...     ...    ...
# 1379                  0.038548  ...  57.0  2.0  17.0  30.0  0.8550  44.92
# 1380                  0.053651  ...  48.0  2.0  17.0  28.0  0.8550  44.92
# 1381                  0.049349  ...  57.0  2.0  17.0  29.0  0.8550  44.92
# 1382                  0.050399  ...  69.0  2.0  12.0  30.0  0.8550  44.92
# 1383                  0.034192  ...  64.0  2.0  22.0  30.0  0.8550  44.92
#
#             ODQ  ID_unique  Country_unique   Region
# 0     99.282421          0            Cuba     Cuba
# 1     99.739738          1            Cuba     Cuba
# 2     99.361739          2            Cuba     Cuba
# 3     99.561273          3            Cuba     Cuba
# 4     99.822774          4            Cuba     Cuba
# ...         ...        ...             ...      ...
# 1379  99.599221       1379           Chile  America
# 1380  99.675799       1380           Chile  America
# 1381  99.641446       1381           Chile  America
# 1382  98.420503       1382           Chile  America
# 1383        NaN       1383           Chile  America
#
# [1384 rows x 230 columns]

# %%
df_CN.to_excel('df_CN_limpio.xlsx', index=False)
